# %% [markdown]
# ## Model to diagnose Breast Cancer

# %% [markdown]
# ### Based on a Support Vector Classifier trained on a dataset of cancerous and non cancerous cells with respective diagnosis.

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
# Load data

df = pd.read_csv(r'C:\Users\91988\Downloads\archive (2)\data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Stat info

df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
# Data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Check for null values

df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# ### Here B = Benign M = Malignant

# %%
# Count Plot
df['diagnosis'] = df['diagnosis'].astype('category')
palette ={'B' : 'lightblue', 'M' : 'red'}
sns.countplot(data = df, x = 'diagnosis', palette = palette)
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
# Corellation plot

df = df.drop(['Unnamed: 32', 'id'], axis = 1)
num_col = df.select_dtypes(include = ['float64', 'int64']).columns
corrdf = df[num_col].corr()
plt.figure(figsize = (20, 10))
sns.heatmap(corrdf, annot = True)
plt.show()

# %%
# Splitting dataset

y = df['diagnosis'].values
x = df.drop('diagnosis', axis = 1).values
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((455, 30), (455,), (114, 30), (114,))

# %%
# Defining the SVC model

svc = SVC(probability = True)
svc.fit(x_train, y_train)
y_pred_svc = svc.predict(x_test)

# %%
# Compare some predictions to actual values

print(y_test[0:10])
print(y_pred_svc[0:10])
# Out:
# ['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B']
# Categories (2, object): ['B', 'M']
# ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B']

# %% [markdown]
# ### The defined model is very accurate as seen in its performance on the test set.

# %%
# Checking accuracy of model

print(accuracy_score(y_pred_svc, y_test))
# Out:
# 0.9473684210526315

# %% [markdown]
# ### Compare it to other model based on Kneighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Train model

#KNeighbors Classifier
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(x_train, y_train)
y_pred_knn = knn.predict(x_test)

# %%
# Compare actual and predicted values

print(y_test[0:10])
print(y_pred_knn[0:10])
# Out:
# ['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B']
# Categories (2, object): ['B', 'M']
# ['B' 'M' 'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B']

# %%
# Accuracy Score

print(accuracy_score(y_pred_knn, y_test))
# Out:
# 0.956140350877193

# %% [markdown]
# ### It is slightly higher than that of SVC

# %% [markdown]
# ## Classification Report

# %%
# SVC
print(classification_report(y_test, y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.92      1.00      0.96        71
#            M       1.00      0.86      0.92        43
#
#     accuracy                           0.95       114
#    macro avg       0.96      0.93      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
# KNN
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      1.00      0.97        71
#            M       1.00      0.88      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.94      0.95       114
# weighted avg       0.96      0.96      0.96       114
